# %% [markdown]
# # Standard Library
#
# :::{note}
# Reference document for this section:
#
# - The Python Standard Library documentation:
#   <https://docs.python.org/3/library/index.html>
# - Python Essential Reference, David Beazley, Addison-Wesley Professional
#   :::
#
# ## `os` module: operating system functionality
#
# _"A portable way of using operating system dependent functionality."_
#
# ### Directory and file manipulation
#
# Current directory:

# %%
import os
os.getcwd()
# Out:
# '/home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language'

# %% [markdown]
# List a directory:

# %%
os.listdir(os.curdir)
# Out:
# ['reusing_code.md',
#  'test.py',
#  'my_file.py',
#  'exceptions.md',
#  'demo2.py',
#  'python_language.md',
#  'python-logo.png',
#  'basic_types.md',
#  'demo.py',
#  'standard_library.md',
#  '__pycache__',
#  'data.txt',
#  'functions.md',
#  'solutions',
#  'oop.md',
#  'workfile',
#  'control_flow.md',
#  'first_steps.md',
#  'io.md']

# %% [markdown]
# Make a directory:

# %%
os.mkdir('junkdir')
'junkdir' in os.listdir(os.curdir)
# Out:
# True

# %% [markdown]
# Rename the directory:

# %%
os.rename('junkdir', 'foodir')
'junkdir' in os.listdir(os.curdir)
# Out:
# False

# %%
'foodir' in os.listdir(os.curdir)
# Out:
# True

# %%
os.rmdir('foodir')
'foodir' in os.listdir(os.curdir)
# Out:
# False

# %% [markdown]
# Delete a file:

# %%
fp = open('junk.txt', 'w')
fp.close()
'junk.txt' in os.listdir(os.curdir)
# Out:
# True

# %%
os.remove('junk.txt')
'junk.txt' in os.listdir(os.curdir)
# Out:
# False

# %% [markdown]
# ### `os.path`: path manipulations
#
# `os.path` provides common operations on pathnames.

# %%
fp = open('junk.txt', 'w')
fp.close()
a = os.path.abspath('junk.txt')
a
# Out:
# '/home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/junk.txt'

# %%
os.path.split(a)
# Out:
# ('/home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language',
#  'junk.txt')

# %%
os.path.dirname(a)
# Out:
# '/home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language'

# %%
os.path.basename(a)
# Out:
# 'junk.txt'

# %%
os.path.splitext(os.path.basename(a))
# Out:
# ('junk', '.txt')

# %%
os.path.exists('junk.txt')
# Out:
# True

# %%
os.path.isfile('junk.txt')
# Out:
# True

# %%
os.path.isdir('junk.txt')
# Out:
# False

# %%
os.path.expanduser('~/local')
# Out:
# '/home/runner/local'

# %%
os.path.join(os.path.expanduser('~'), 'local', 'bin')
# Out:
# '/home/runner/local/bin'

# %% [markdown]
# ### Running an external command

# %%
return_code = os.system('ls')
# Out:
# __pycache__
# basic_types.md
# control_flow.md
# data.txt
# demo.py
# demo2.py
# exceptions.md
# first_steps.md
# functions.md
# io.md
# junk.txt
# my_file.py
# oop.md
# python-logo.png
# python_language.md
# reusing_code.md
# solutions
# standard_library.md
# test.py
# workfile

# %% [markdown]
# :::{note}
# Alternative to `os.system`
#
# A noteworthy alternative to `os.system` is the [sh
# module](https://amoffat.github.com/sh/). Which provides much more convenient
# ways to obtain the output, error stream and exit code of the external command.
#
# ```python
# import sh
# com = sh.ls()
#
# print(com)
# basic_types.md    exceptions.md   oop.md               standard_library.md
# control_flow.md   first_steps.md  python_language.md
# demo2.py          functions.md    python-logo.png
# demo.py           io.md           reusing_code.md
#
# type(com)
# Out[33]: str
# ```
#
# :::
#
# ### Walking a directory
#
# `os.path.walk` generates a list of filenames in a directory tree.

# %%
for dirpath, dirnames, filenames in os.walk(os.curdir):
    for fp in filenames:
        print(os.path.abspath(fp))
# Out:
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/reusing_code.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/test.py
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/my_file.py
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/exceptions.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/demo2.py
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/python_language.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/python-logo.png
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/basic_types.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/demo.py
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/standard_library.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/data.txt
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/functions.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/oop.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/workfile
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/control_flow.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/junk.txt
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/first_steps.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/io.md
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/demo.cpython-312.pyc
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/demo2.cpython-312.pyc
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/path_site.py
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/dir_sort.py
# /home/runner/work/scientific-python-lectures/scientific-python-lectures/intro/language/test_dir_sort.py

# %% [markdown]
# ### Environment variables:
#
# ```ipython
# In [2]: os.environ.keys()
# Out[2]: KeysView(environ({'SHELL': '/bin/bash', 'PWD': '/home/mb312', 'LOGNAME': 'mb312', 'HOME': '/home/mb312', 'TERM': 'xterm', 'USER': 'mb312', 'SHLVL': '1', 'PATH': '/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/snap/bin', 'MAIL': '/var/mail/mb312', '_': '/usr/bin/python3', 'LC_CTYPE': 'C.UTF-8'}))
#
# In [3]: os.environ['SHELL']
# Out[3]: '/bin/bash'
# ```

# %% [markdown]
# ## `shutil`: high-level file operations
#
# The `shutil` provides useful file operations:
#
# - `shutil.rmtree`: Recursively delete a directory tree.
# - `shutil.move`: Recursively move a file or directory to another location.
# - `shutil.copy`: Copy files or directories.
#
# ## `glob`: Pattern matching on files
#
# The `glob` module provides convenient file pattern matching.
#
# Find all files ending in `.txt`:

# %%
import glob
glob.glob('*.txt')
# Out:
# ['data.txt', 'junk.txt']

# %% [markdown]
# ## `sys` module: system-specific information
#
# System-specific information related to the Python interpreter.
#
# **Which version of Python** are you running and where is it installed:

# %%
import sys
sys.platform
# Out:
# 'linux'

# %%
sys.version
# Out:
# '3.12.12 (main, Oct 10 2025, 01:01:16) [GCC 13.3.0]'

# %%
sys.prefix
# Out:
# '/opt/hostedtoolcache/Python/3.12.12/x64'

# %% [markdown]
# `sys.argv` gives you a **list of command line arguments** passed to a Python
# script. It is useful when you call as script with e.g. `python my_script.py some arguments`. Inside the `my_arguments.py` script, you can get the passed arguments (here ['some', 'arguments']) with `sys.argv`.
#
# `sys.path` is a list of strings that specifies the search path for
# modules. Initialized from `PYTHONPATH`:

# %%
sys.path
# Out:
# ['/opt/hostedtoolcache/Python/3.12.12/x64/lib/python312.zip',
#  '/opt/hostedtoolcache/Python/3.12.12/x64/lib/python3.12',
#  '/opt/hostedtoolcache/Python/3.12.12/x64/lib/python3.12/lib-dynload',
#  '',
#  '/opt/hostedtoolcache/Python/3.12.12/x64/lib/python3.12/site-packages']

# %% [markdown]
# ## `pickle`: easy persistence
#
# Useful to store arbitrary objects to a file. Not safe or fast!

# %%
import pickle
l = [1, None, 'Stan']
with open('test.pkl', 'wb') as file:
    pickle.dump(l, file)

# %%
with open('test.pkl', 'rb') as file:
    out = pickle.load(file)

# %%
out
# Out:
# [1, None, 'Stan']

# %% [markdown]
# ## Exercises
#
# ::: {exercise-start}
# :label: data-file-ex
# :class: dropdown
# :::
#
# Write a function that will load the column of numbers in `data.txt` and
# calculate the min, max and sum values. Use no modules except those in the
# standard library; specifically, do not use Numpy.
#
# {download}`data.txt`:
#
# ::: {literalinclude} data.txt
#
# :::
#
# ::: {exercise-end}
# :::
#
# ::: {solution-start} data-file-ex
# :class: dropdown
# :::

# %%
def load_data(filename):
    fp = open(filename)
    data_string = fp.read()
    fp.close()

    data = []
    for x in data_string.split():
        # Data is read in as a string. We need to convert it to floats
        data.append(float(x))

    # Could instead use the following one line with list comprehensions!
    # data = [float(x) for x in data_string.split()]
    return data

# %%
data = load_data("data.txt")
# Python provides these basic math functions.
print(f"min: {min(data):f}")
print(f"max: {max(data):f}")
print(f"sum: {sum(data):f}")
# Out:
# min: 10.200000
# max: 61.300000
# sum: 237.900000

# %% [markdown]
# ::: {solution-end}
# :::
#
# ::: {exercise-start}
# :label: dir-sort-ex
# :class: dropdown
# :::
#
# Implement a _script_ that takes a directory name as argument, and
# returns the list of '.py' files, sorted by name length.
#
# **Hint:** try to understand the docstring of list.sort
#
# ::: {exercise-end}
# :::
#
# ::: {solution-start} dir-sort-ex
# :class: dropdown
# :::
#
# ::: {literalinclude} solutions/dir_sort.py
#
# :::
#
# ::: {solution-end}
# :::

# %% [markdown]
# ::: {exercise-start}
# :label: path-site-ex
# :class: dropdown
# :::
#
# Write a program to search your `PYTHONPATH` for the module `site.py`.
#
# ::: {exercise-end}
# :::
#
# ::: {solution-start} path-site-ex
# :class: dropdown
# :::
#
# ::: {literalinclude} solutions/path_site.py
#
# :::
#
# ::: {solution-end}
# :::
